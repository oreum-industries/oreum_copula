# %% [markdown]
# **Oreum Industries Internal Project, 2024Q1**
#
# ---
#
# # 101_ModelA1.ipynb
#
# ### Oreum Copula Demo in `oreum_copula`
#
# Implementation of Bayesian Copula-Based Expected Loss Cost Forecasting.
# We use highly advanced Bayesian inference techniques and a Bayesian workflow,
# specifically using the `pymc` & `arviz` ecosystem.
#
# Here we demonstrate an E2E workflow for novel models of increasing sophistication.
# We evaluate the behaviour and performance of the models throughout the workflows,
# including several state-of-the-art methods unavailable to conventional
# max-likelihood / machine-learning models.
#
# **In this Notebook:**
#
# + Build & evaluate `ModelA1`, with partial archtecture: an extension of `ModelA0` **with** a Gaussian copula (but without Jacobian adjustment)
#
#
# ## Contents
#
# + [Setup](#Setup)
#
# + [0. Synthesize Dataset](#0.-Synthesize-Dataset)
#
# + [1. Model Description](#1.-Model-Description)
#
# + [2. Custom Bayesian Model `ModelA1`](#2.-Custom-Bayesian-Model-`ModelA1`)
#
# ---

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import sys
from copy import deepcopy
from pathlib import Path

import arviz as az
import numpy as np
import pandas as pd

# from IPython.display import Markdown, display
from oreum_core import eda
from oreum_core import model_pymc as mt
from pyprojroot.here import here

# prepend local project src files
module_path = here('src').resolve(strict=True)
if str(module_path) not in sys.path:
    sys.path.insert(0, str(module_path))    # sys.path.append(str(module_path))

# autoreload local modules to allow local dev
# %load_ext autoreload
# %autoreload 2
import warnings  # noqa suppress seaborn, it's far too chatty

from engine import logger, utils  #.trainer import Trainer
from model import copula
from synthetic.create_copula import CopulaBuilder

warnings.simplefilter(action='ignore', category=FutureWarning)  # noqa
import seaborn as sns  # noqa
# Out:
# /Users/jon/miniforge/envs/oreum_copula/lib/python3.11/site-packages/pymc/util.py:38: FutureWarning: dataset_to_point_list has been moved to backends.arviz. Importing from util will fail in a future release.
#   warnings.warn(

# %% [markdown]
# ##### Notebook config

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sns.set(style='darkgrid', palette='muted', context='notebook', 
        rc={'savefig.dpi':300, 'figure.figsize': (12, 3)})

log = logger.get_logger('101_ModelA1', notebook=True)
_ = logger.get_logger('oreum_core', notebook=True)

# %% [markdown]
# ## Local Functions and Global Vars

# %%
RSD = 42
RNG = np.random.default_rng(seed=RSD)

# %% [markdown]
# ## Data Connections and Helper Objects

# %%
figio = eda.FigureIO(here(Path('plots')).resolve(strict=True))
mdlio = mt.PYMCIO(here(Path('data', 'models')).resolve(strict=True))

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # 0. Load Dataset

# %% [markdown]
# ## 0.1 Synthetise Demo Dataset for Project

# %% [markdown]
# See `000_Intro.ipynb` for details

# %%
cb = CopulaBuilder()
df_all = cb.create(nobs=60)
print(cb.ref_vals)
eda.display_ht(df_all)
# Out:
# {'c_r': -0.7, 'c_cov': array([[ 1. , -0.7],
#        [-0.7,  1. ]]), 'm0_kind': 'lognorm', 'm1_kind': 'lognorm', 'm0_params': {'mu': 0.2, 'sigma': 0.5}, 'm1_params': {'mu': 2.0, 'sigma': 1.0}}
#         c0    c1    u0    u1    m0     m1   u0x   u1x   m0x    m1x
# oid
# i000 -0.68 -0.12  0.25  0.45  0.87   6.54  0.08  0.52  0.61   7.75
# i001 -0.33  1.06  0.37  0.85  1.04  21.25  0.42  0.32  1.10   4.58
# i002  1.29 -2.30  0.90  0.01  2.33   0.74  0.04  0.77  0.51  15.57
# i057 -0.27 -0.14  0.39  0.44  1.07   6.43  0.75  0.11  1.71   2.16
# i058 -0.21  0.22  0.42  0.59  1.10   9.23  0.89  0.83  2.26  19.14
# i059 -1.57  1.38  0.06  0.92  0.56  29.49  0.89  0.80  2.28  16.95
# 'Shape: (60, 10), Memsize 0.0 MB'

# %%
perm = RNG.permutation(df_all.index.values)
df_train = df_all.loc[perm[:50]].sort_index()
df_holdout = df_all.loc[perm[50:]].sort_index()
# eda.describe(df_train, nobs=3, get_counts=False)
eda.display_ht(df_train)
# Out:
#         c0        c1    u0    u1    m0     m1   u0x   u1x   m0x    m1x
# oid
# i000 -0.68 -1.22e-01  0.25  0.45  0.87   6.54  0.08  0.52  0.61   7.75
# i003 -0.24 -4.62e-03  0.41  0.50  1.08   7.36  0.49  0.66  1.21  11.21
# i004 -0.31 -3.46e-01  0.38  0.36  1.04   5.23  0.33  0.37  0.98   5.35
# i056 -0.01 -1.11e+00  0.50  0.13  1.21   2.44  0.89  0.02  2.27   0.90
# i057 -0.27 -1.39e-01  0.39  0.44  1.07   6.43  0.75  0.11  1.71   2.16
# i059 -1.57  1.38e+00  0.06  0.92  0.56  29.49  0.89  0.80  2.28  16.95
# 'Shape: (50, 10), Memsize 0.0 MB'

# %% [markdown]
# ## 0.2 Quick EDA to remind how the data looks

# %% [markdown]
# ### 0.2.1 Jointplot marginals $M_{0}$, $M_{1}$

# %%
f = eda.plot_joint_numeric(data=df_train, ft0='m0', ft1='m1', kind='kde+scatter', colori=2, 
            subtitle='Observed Marginals with Copula Correlation')

# %% [markdown]
# **Observe:**
#
# + Note the negative correlation $\rho \approx -0.4$ and the skewed marginals with different scales

# %% [markdown]
# ### 0.2.2 Plot product $y = M_{0} * M_{1}$ to motivate correct estimation of copula

# %%
dfp = pd.concat((df_train[['m0', 'm1']], df_train[['m0x', 'm1x']]\
                 .rename(columns={'m0x':'m0', 'm1x': 'm1'})),
                axis=0, ignore_index=True)
dfp['corr_kind'] = np.repeat(['j_corr', 'j_uncorr'], repeats=len(df_train))
dfp['y'] = dfp[['m0', 'm1']].product(axis=1)
pal = sns.color_palette(['C2', 'C3'])
f = eda.plot_smrystat_grp(dfp, grp='corr_kind', val='y', palette=pal)

# %% [markdown]
# **Observe:**
#
# + The (bootstrapped) sum of `j_uncorr` ($\mu \approx 650$) is almost always much higher than for `j_corr` ($\mu \approx 500$)
# + This shows that even if we estimated each marginal correctly, if our model were to (erroroneously) ignore the coupled covariance between our marginals `m0`, `m1`, we would (erroneously) overestimate the joint distribution total value

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # 1. Model Description

# %% [markdown]
# ## 1.1 Estimate Marginals

# %% [markdown]
# In `ModelA1` we continue to estimate the marginals using linear sub-models, but we couple them as a joint distrbution, via a copula function shown in in $\S1.2$
#
# We have two marginals $M_{0}$ and $M_{1}$, which we estimate as both being $\text{LogNormal}$ distributions (because we
# want to keep this example simple):
#
# $$
# \begin{aligned}
# M_{0}\\
# \beta_{M_{0}}^{j0} &\sim \text{Normal}(\mu, \sigma) \\
# \sigma_{M_{0}} &\sim \text{InverseGamma}(\alpha, \beta) \\
# \mathcal{L}\ \hat{M_{0}} &\sim \text{LogNormal}(\beta_{M_{0}}^{T}\mathbf{x}_{i}^{j0}, \sigma_{M_{0}}) \\
# \\
# M_{1}\\
# \beta_{M_{1}}^{j1} &\sim \text{Normal}(\mu, \sigma) \\
# \sigma_{M_{1}} &\sim \text{InverseGamma}(\alpha, \beta) \\
# \mathcal{L}\ \hat{M_{1}} &\sim \text{LogNormal}(\beta_{M_{1}}^{T}\mathbf{x}_{i}^{j1}, \sigma_{M_{1}}) \\
# \end{aligned}
# $$
#
# where:
#
# + We treat marginal $M_{0}$ and $M_{1}$ separately, although both are estimated as a $\text{LogNormal}$
# + Observations $\mathbf{x}_{i}$ have features $j$, and we define simple linear coefficients $\beta_{M_{0}}^{j0}$
# + Note in this example synthetic dataset we dont have any features, so we just set an intercept and retain the formality
#   of the structure for general later usage
# + The linear sub-models e.g. $\beta_{M_{0}}^{T}\mathbf{x}^{j0}$ let us regress onto (potentially independent) subsets
#   of features $j0$ and $j1$

# %% [markdown]
# ## 1.2 Estimate Copula

# %% [markdown]
# This is where we depart from the naive `ModelA0`, by introducing a Gaussian copula function to capture the covariance
# between the marginals.
#
# We construct a reversing process to transform the observed marginals to a latent copula
# and evidence the model at the copula $\mathcal{L}\ \hat{C}$ _while still continuing_  to evidence at the marginals $(\mathcal{L}\ \hat{M_{0}}, \mathcal{L}\ \hat{M_{1}})$
#
#
#
# #### 1. Transform observed marginals ($M_{0}$, $M_{1}$) to $\text{Uniform}$ ($U_{0}$, $U_{1}$) via their assumed CDFs:
#
# $$
# \begin{aligned}
# U_{0} &= \mathfrak{m_{0}}\Phi(M_{0}) \\
# U_{1} &= \mathfrak{m_{1}}\Phi(M_{1})
# \end{aligned}
# $$
#
# where:
# + $\mathfrak{m_{0}}\Phi$ and $\mathfrak{m_{1}}\Phi$ is the CDF to which we assume the observed marginal belongs
# + i.e we might assume the marginal $M_{0}$ is LogNormal distributed, so $\mathfrak{m_{0}}\Phi = \text{LogNormalCDF}$
#
#
# #### 2. Transform the $\text{Uniform}$ marginals to Normal ($C_{0}$, $C_{1}$) via a Normal InverseCDF
#
# $$
# \begin{aligned}
# (C_{0}, C_{1}) &= \text{MvNormal}(\mu=0, \sigma=1)\Phi^{-1}([U_{0}, U_{1}])
# \end{aligned}
# $$
#
# where:
# + $\text{MvNormal}(\mu=0, \sigma=1)\Phi^{-1}$ is the InverseCDF of a Multivariate Normal (without covariance)
#   or equivalently, two entirely separate Normal Inverse CDFs
# + Note this is not directly the copula likelihood function, just an transformation of the marginals into
#   the same distribution family as the copula function
#
# #### 3. Create a latent covariance structure $\Sigma$ to use in our Copula function
#
# $$
# \begin{aligned}
# L &\sim \text{LKJCholesky}(2), \; R \sim \text{LKJCorr}(2) \\
# \sigma &\sim \text{InverseGamma}(\alpha, \beta) \\
# \Sigma &\sim LL^{T} = diag(\sigma) * R * diag(\sigma)
# \end{aligned}
# $$
#
# where:
# + Either way we build $\Sigma$ we end up with a latent covariance matrix to use in the next step
#
#
# #### 4. Evaluate likelihood $\hat{C}$ of the transformed marginals using a covarying MVNormal function:
#
# $$
# \begin{aligned}
# \mathcal{L}\ \hat{C} &\sim \text{MvNormal}(\mu=0, \Sigma, \text{observed}=(C_{0}, C_{1}))
# \end{aligned}
# $$
#
# where:
# + For convenience we refer to $(\hat{C_{0}}, \hat{C_{1}})$ as simply $\hat{C}$

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # 2. Custom Bayesian Model `ModelA1`

# %% [markdown]
# This is the first of many Bayesian models that we will create in this project. Refer to `000_Intro.ipynb` $\S \text{Preamble}$
# for the myriad reasons this is a better general method to use.

# %% [markdown]
# ## 2.0 Prepare & Transform Dataset for Linear Model

# %% [markdown]
# This is a preparatory step to transform the observational data into a form for
# use in the custom Bayesian models. We will use the transformed datasets `dfx_*`
# in all subsequent models where possible.
#
# NOTE:
#
# + For this example Notebook we _will_ partition into `train` & `holdout` sets
#   (see `README.md ## 5. Data Standards` for terminology)
# + We will (as usual) evaluate in-sample using Pareto-smoothed Leave-One-Out (LOO-PIT) cross-validation testing
# + We will also evaluate out-of-sample (because we have the ground truth) to demonstrate model behaviour
# + This means we still follow our standard process for preparation, transformation, standardization for `dfa` and `dfb`
# + Our model architecture wants two dataframes `obs_m0` and `obs_m1`, one per marginal - and we will make these based on arg `kind`
# + We have no features for `m0` and `m1`, so the linear sub-models have to be intercept-only.
# + Here we must also forget anything we know about the construction of the synthetic data, this is all we have.

# %% [markdown]
# ### Fit and transform `train` set

# %%
dfx_creator_m0 = utils.ProjectDFXCreator(kind='m0')
dfx_m0_train = dfx_creator_m0.get_dfx(df_train)
eda.describe(dfx_m0_train)

dfx_creator_m1 = utils.ProjectDFXCreator(kind='m1')
dfx_m1_train = dfx_creator_m1.get_dfx(df_train)
eda.describe(dfx_m1_train)
# Out:
#               32     4    37    dtype  count_null  count_inf  count_zero  \
# ft
# index: oid  i040  i006  i046   object           0        NaN         NaN
# m0          0.87  1.47  1.46  float64           0        0.0         0.0
# intercept    1.0   1.0   1.0  float64           0        0.0         0.0
#
#            count_unique   top freq    sum  mean  std   min   25%   50%   75%  \
# ft
# index: oid           50  i000    1    NaN   NaN  NaN  i000   NaN   NaN   NaN
# m0                  NaN   NaN  NaN  64.71  1.29  0.5  0.42  0.89  1.19  1.72
# intercept           NaN   NaN  NaN  50.00   1.0  0.0   1.0   1.0   1.0   1.0
#
#              max
# ft
# index: oid  i059
# m0          2.49
# intercept    1.0
# 'Shape: (50, 3), Memsize 0.0 MB'
#                 4    34    41    dtype  count_null  count_inf  count_zero  \
# ft
# index: oid   i006  i042  i050   object           0        NaN         NaN
# m1          12.15  2.96  8.62  float64           0        0.0         0.0
# intercept     1.0   1.0   1.0  float64           0        0.0         0.0
#
#            count_unique   top freq    sum  mean   std   min   25%   50%  \
# ft
# index: oid           50  i000    1    NaN   NaN   NaN  i000   NaN   NaN
# m1                  NaN   NaN  NaN  493.0  9.86  8.25  0.89  4.47  7.84
# intercept           NaN   NaN  NaN   50.0   1.0   0.0   1.0   1.0   1.0
#
#               75%    max
# ft
# index: oid    NaN   i059
# m1          12.93  45.47
# intercept     1.0    1.0
# 'Shape: (50, 3), Memsize 0.0 MB'

# %% [markdown]
# ### Transform `holdout` set

# %%
dfx_m0_holdout = dfx_creator_m0.get_dfx(df_holdout, in_sample=False)
eda.describe(dfx_m0_holdout)

dfx_m1_holdout = dfx_creator_m1.get_dfx(df_holdout, in_sample=False)
eda.describe(dfx_m1_holdout)
# Out:
#                4     8     7    dtype  count_null  count_inf  count_zero  \
# ft
# index: oid  i013  i043  i036   object           0        NaN         NaN
# m0          1.03  1.52  2.05  float64           0        0.0         0.0
# intercept    1.0   1.0   1.0  float64           0        0.0         0.0
#
#            count_unique   top freq    sum  mean   std   min   25%   50%   75%  \
# ft
# index: oid           10  i001    1    NaN   NaN   NaN  i001   NaN   NaN   NaN
# m0                  NaN   NaN  NaN  13.73  1.37  0.48  0.86  1.05  1.21  1.49
# intercept           NaN   NaN  NaN  10.00   1.0   0.0   1.0   1.0   1.0   1.0
#
#              max
# ft
# index: oid  i058
# m0          2.33
# intercept    1.0
# 'Shape: (10, 3), Memsize 0.0 MB'
#                 4     6     1    dtype  count_null  count_inf  count_zero  \
# ft
# index: oid   i013  i033  i002   object           0        NaN         NaN
# m1          13.91  4.48  0.74  float64           0        0.0         0.0
# intercept     1.0   1.0   1.0  float64           0        0.0         0.0
#
#            count_unique   top freq    sum  mean   std   min   25%   50%  \
# ft
# index: oid           10  i001    1    NaN   NaN   NaN  i001   NaN   NaN
# m1                  NaN   NaN  NaN  82.54  8.25  6.15  0.74  4.38  5.99
# intercept           NaN   NaN  NaN  10.00   1.0   0.0   1.0   1.0   1.0
#
#               75%    max
# ft
# index: oid    NaN   i058
# m1          11.89  21.25
# intercept     1.0    1.0
# 'Shape: (10, 3), Memsize 0.0 MB'

# %% [markdown]
# ---

# %% [markdown]
# ## 2.1 Build Model Object

# %% [markdown]
# `ModelA1` model imported from `src.model.copula.py` where it is fully defined

# %%
mdla1 = copula.ModelA1(obs_m0=dfx_m0_train, obs_m1=dfx_m1_train,  obs_nm='dfx_train',
                        dfx_creatord={'m0':dfx_creator_m0, 'm1':dfx_creator_m1})
mdla1.build()
utils.display_rvs(mdla1)
mdla1.debug()
# Out:
# 'RVs for mdla1, v1.1.0, dfx_train'
# beta_m0 ~ Normal(0, 1)
# beta_m1 ~ Normal(0, 1)
# sigma ~ InverseGamma(5, 4)
# lkjcc ~ _lkjcholeskycov(2, 2, InverseGamma(5, 4))
# pot_mhat ~ Potential(f(sigma, beta_m1, beta_m0))
# pot_chat ~ Potential(f(lkjcc, sigma, beta_m1, beta_m0))
# u ~ Deterministic(f(sigma, beta_m1, beta_m0))
# c ~ Deterministic(f(sigma, beta_m1, beta_m0))
# lkjcc_corr ~ Deterministic(f(lkjcc))
# lkjcc_stds ~ Deterministic(f(lkjcc))
# point={'beta_m0': array([0.]), 'beta_m1': array([0.]), 'sigma_log__': array([0., 0.]), 'lkjcc_cholesky-cov-packed__': array([0., 0., 0.])}
#
# No problems found
# point={'beta_m0': array([0.]), 'beta_m1': array([0.]), 'sigma_log__': array([0., 0.]), 'lkjcc_cholesky-cov-packed__': array([0., 0., 0.])}
# 'Ran 2 checks: [test: assert_no_rvs(logp), debug: random]'

# %%
fqn = mdlio.write_graph(mdla1)  # output model graph to prove built
f = figio.read(fqn=fqn, title=f'Model architecture\n{mdla1.mdl_id}', figsize=(12, 6))

# %% [markdown]
# **Observe:**
#
# Compare to the graph for `mdla0`, several new nodes including:
#
# + Deterministics `u` and `c` transforming the observed marginals `m`
# + Covariance structures `lkjcc*` helping to create the latent copula structure
# + Potentials `pot_mhat`, `pot_chat` to evidence against the observed marginals and latent copula respectively
# + Deterministics `mhat`, `yhat` recording the marginals and joint product for forward-sampling PPC later

# %% [markdown]
# ---

# %% [markdown]
# ## 2.2 Sample Prior Predictive, View Diagnostics

# %%
mdla1.sample_prior_predictive(var_names=mdla1.rvs_ppc + mdla1.rvs_unobs + mdla1.rvs_det, replace=True)
mdla1.idata
# Out:
# /Users/jon/workspace/oreum/oreum_core/oreum_core/model_pymc/base.py:167: UserWarning: The effect of Potentials on other parameters is ignored during prior predictive sampling. This is likely to lead to invalid or biased predictive samples.
#   prior_pred = pm.sample_prior_predictive(**{**kws, **kwargs})
# Inference data with groups:
# 	> prior
# 	> constant_data

# %% [markdown]
# ### 2.2.0 Hacky post-process `idata` to resolve the PPC on Potentials putting things in wrong place

# %%
# 1. Create `observed_data` (copy `constant_data`, rename, drop the rest)
if 'observed_data' not in mdla1.idata.groups():
    mdla1.idata.add_groups(
        observed_data=deepcopy(
            (mdla1.idata.constant_data
            .drop_vars(['x0', 'x1', 'm_nm', 'y'])
            .drop_dims(['x0_nm', 'x1_nm'])
            .rename_vars({'m': 'mhat'})
            .swap_dims({'m_nm': 'mhat_nm'})
            .assign_coords({'mhat_nm': ['m0hat', 'm1hat']})     
            )))

# 2. Create `prior_predictive` (copy `prior`, drop the rest)
if 'prior_predictive' not in mdla1.idata.groups():
    mdla1.idata.add_groups(prior_predictive=deepcopy(
        (mdla1.idata.prior
         .drop_vars(mdla1.rvs_unobs + mdla1.rvs_det)
         .drop_dims(['x0_nm', 'x1_nm', 's_nm', 'u_nm', 'c_nm', 
         'lkjcc_dim_0', 'lkjcc_corr_dim_0', 'lkjcc_corr_dim_1', 'lkjcc_stds_dim_0'])
         )))
mdla1.idata
# Out:
# Inference data with groups:
# 	> prior
# 	> prior_predictive
# 	> observed_data
# 	> constant_data

# %% [markdown]
# ### 2.2.1 Evaluate Prior PPC

# %%
GRP = 'prior'
f = mt.plot_ppc(mdl=mdla1, group=GRP, var_names=mdla1.rvs_ppc, flatten=['oid'], insamp=True)

# %% [markdown]
# **Observe:**
#
# + Terrible fit as expected, but the range is valid

# %% [markdown]
# ### 2.2.2 Evaluate priors and hyperpriors on linear model

# %%
f = mt.facetplot_krushke(mdl=mdla1, group=GRP, txtadd='hyperpriors on marginals',
        rvs=mdla1.rvs_marg, m=4, rvs_hack=1)

# %% [markdown]
# **Observe:**
#
# + Linear submodel priors seem reasonable

# %% [markdown]
# ### 2.2.3 Evaluate priors on Copula Structure

# %% [markdown]
# #### 2.2.3.1 LKJCholeskyCov (decomposition and stds)

# %%
f = mt.facetplot_krushke(mdl=mdla1, group='prior', txtadd='LKJCholeskyCov',rvs=mdla1.rvs_lkjcc + ["lkjcc_stds"], m=3)

# %% [markdown]
# **Observe:**
#
# + LKJCC priors seem reasonable

# %% [markdown]
# #### 2.2.3.2 LKJCholeskyCov (Correlation Matrix)

# %%
f = mt.plot_lkjcc_corr(mdl=mdla1, group='prior')

# %% [markdown]
# **Observe:**
#
# + Correlation looks reasonable

# %% [markdown]
# #### 2.2.3.3 Check `u0`, `u1` post-transformation: Marginal -> marginal_dist.CDF -> Uniform

# %%
rv = 'u'
cols = mdla1.coords[f'{rv}_nm']
x = az.extract(mdla1.idata, group='prior', var_names=rv).values
dfp_u = pd.DataFrame(np.nanmean(x, axis=2), columns=cols)
f = eda.plot_joint_numeric(data=dfp_u, ft0=cols[0], ft1=cols[1], kind='kde+scatter', 
            colori=1, txtadd='Prior PPC Latent Uniform Marginals (mean of samples)')

# %% [markdown]
# **Observe**
#
# + `u0`, `u1` are in the valid range $[0,1]$
# + Clearly our LKJCC priors and transformations allow for coupled covariance, great

# %% [markdown]
# #### 2.2.3.4 Check `c1`, `c2` post-transformation: Uniform -> normal.invCDF -> MvN

# %% [markdown]
# A) Mean of samples

# %%
rv = 'c'
cols = mdla1.coords[f'{rv}_nm']
x = az.extract(mdla1.idata, group='prior', var_names=rv).values
dfp_y_u = pd.DataFrame(np.nanmean(x, axis=2), columns=cols)
f = eda.plot_joint_numeric(data=dfp_y_u, ft0=cols[0], ft1=cols[1], kind='kde+scatter', 
            txtadd='Prior PPC Latent Copula (mean of samples)')

# %% [markdown]
# **Observe:**
#
# + `c0`, `c1` are in a reasonable range and location
# + Clearly our LKJCC priors and transformations allow for coupled covariance, great
# + Note the prior covariance $\rho \approx -0.7$ is also reasonable in sign and magnitude, suggesting that our model
#   will be capable of capturing the covariance seen in the data

# %% [markdown]
# B) Quantiles of samples

# %%
qs = [0.03, 0.25, 0.5, 0.75, 0.97]
dfp_c_q = pd.DataFrame(np.quantile(x, qs, axis=2).reshape(len(qs)*mdla1.n, 2), columns=cols)
dfp_c_q['q'] = np.repeat([f'{q}'  for q in qs], mdla1.n)
f = eda.plot_joint_numeric(data=dfp_c_q, ft0=cols[0], ft1=cols[1], hue='q', kind='kde',
            txtadd='Prior PPC Latent Copula (quantiles of samples)')

# %% [markdown]
# **Observe:**
#
# + Covering a lot of the space: seems reasonable and not overly informative

# %% [markdown]
# ---

# %% [markdown]
# ## 2.3 Sample Posterior, View Diagnostics

# %% [markdown]
# Use hacky caching because these copula architectures can take a while to sample

# %%
try:
    mdla1.update_idata(idata=mdlio.read_idata(mdl=mdla1))
except FileNotFoundError:    
    mdla1.sample(progressbar=True)
    mdla1.sample_posterior_predictive(store_ppc=True, ppc_insample=True, var_names=mdla1.rvs_ppc + mdla1.rvs_det)
    mdlio.write_idata(mdl=mdla1)

# %%
f = mt.plot_trace(mdl=mdla1, rvs=mdla1.rvs_unobs, kind='trace')
f = mt.plot_energy(mdl=mdla1)
smry = mt.get_summary(mdl=mdla1, rvs=mdla1.rvs_unobs)
smry
# Out:
#                      mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# sigma[s0]           1.123  0.222   0.750    1.537      0.007    0.005
# sigma[s1]           2.282  0.450   1.532    3.171      0.014    0.010
# beta_m0[intercept]  0.191  0.052   0.090    0.286      0.001    0.001
# beta_m1[intercept]  1.944  0.112   1.745    2.145      0.003    0.002
# lkjcc[0]            0.394  0.078   0.254    0.541      0.002    0.002
# lkjcc[1]           -0.314  0.073  -0.455   -0.186      0.002    0.002
# lkjcc[2]            0.277  0.059   0.167    0.388      0.002    0.001
#
#                     ess_bulk  ess_tail  r_hat
# sigma[s0]             1207.0    1202.0    1.0
# sigma[s1]             1040.0    1097.0    1.0
# beta_m0[intercept]    1441.0    1544.0    1.0
# beta_m1[intercept]    1419.0    1301.0    1.0
# lkjcc[0]              1151.0    1045.0    1.0
# lkjcc[1]              1173.0    1176.0    1.0
# lkjcc[2]              1136.0    1306.0    1.0

# %% [markdown]
# **Observe:**
#
# + Posterior distributions reasonably smooth and central
# + Samples well-mixed and well-behaved: `ess_bulk` is good, `r_hat` is good
# + Marginal energy | energy transition looks okay: `E-BFMI > 0.3` so [apparently reasonable](https://python.arviz.org/en/stable/api/generated/arviz.bfmi.html#arviz.bfmi)

# %% [markdown]
# ---

# %% [markdown]
# ## 2.4 Evaluate Posterior PPC (In-Sample)

# %% [markdown]
# ### 2.4.1 ECDF plots: univariate marginals $M_{0}$, $M_{1}$

# %%
GRP = 'posterior'
f = mt.plot_ppc(mdl=mdla1, group=GRP, var_names=mdla1.rvs_ppc, insamp=True, logx=True, flatten=['oid'], observed_rug=True)

# %% [markdown]
# **Observe:**
#
# + `m0`: bulk has good fit, tails also good, but a little heavy
# + `m1`: bulk has good fit, tails okay but a little heavy
# + Looks very similar to `mdla0`
#
# > Does this mean we have a good fit? We need to look at the resulting yhat and the covariance...

# %% [markdown]
# ### 2.4.2 ECDF plot $\hat{y}$

# %%
# post-process copy y into observed as yhat so we can work with it / plot it etc
mdla1.idata.observed_data = mdla1.idata.observed_data.assign(yhat=deepcopy(mdla1.idata.constant_data.y))
f = mt.plot_ppc(mdl=mdla1, group=GRP, var_names=['yhat'], insamp=True, ecdf=False, observed_rug=True)
f = mt.plot_ppc(mdl=mdla1, group=GRP, var_names=['yhat'], insamp=True, logx=True, observed_rug=True)

# %% [markdown]
# **Observe:**
#
# + This is a better measure of model fit accounting for covariance: the bulk looks good, the tails are a little overdispersed
# + Looks better than `mdla0`

# %% [markdown]
# ### 2.4.3 Additional In-Sample Evaluations, largely superseded by Retrodictive and LOO-PIT checks, but keep for future reference

# %% [markdown]
# #### 2.4.3.1 Coverage aka Calibration Plot of $\hat{y}$

# %% [markdown]
# This is another way to check model calibration:
# + It's more naive than the ECDF plot because it summarises the samples over credible regions (CR) rather than all samples
# + But it does yield a simple AUC measurement that can be helpful in some cases
# + Kept here mainly for posterity so we can return to use it another time if needed

# %%
dfy = az.extract(mdla1.idata, group='constant_data', var_names=['y'], combined=False,).to_dataframe()
dfyhat = az.extract(mdla1.idata, group='posterior_predictive', var_names=['yhat']).to_dataframe().drop(['chain', 'draw'], axis=1)
df_cov_eloss = mt.calc_ppc_coverage(dfy['y'].values, dfyhat.unstack(0).T.values)
f = eda.plot_coverage(df_cov_eloss)

# %% [markdown]
# **Observe:**
#
# + The `pin_left` method is more appropriate for this positive-only distribution `yhat`
# + The $\text{AUC} \approx 0.031$ is good (can be up to $0.5$), and is half the value seen for `mdla0`

# %% [markdown]
# ### 2.4.3.2: Plot RMSE and $R^{2}$

# %% [markdown]
# These are another way to check model calibration:
#
# + The `RMSE` calc summarises the samples, but does show where the "sweet spot" of the PPC sits, and can be a useful
#   metric to quote in later comparisons, esp with Frequentist models
# + The `Bayesian R2` calc actually uses all the samples and is an up-to-date method
# + Both are kept here mainly for posterity so we can return to use it another time if needed

# %%
dfyhaty = pd.merge(dfyhat.reset_index(), dfy.reset_index(), how='left', on='oid').set_index(['oid', 'chain', 'draw'])
rmse, rmse_qs = mt.calc_rmse(dfyhaty, oid='oid', yhat='yhat', y='y', method='a', qs=True)
_ = eda.plot_rmse_range(rmse, rmse_qs.loc[0.25:0.75], yhat='yhat', y='y', txtadd=f'\n{mdla1.mdl_id}')

df_r2 = mt.calc_bayesian_r2(dfy['y'].values, dfyhat.unstack(0).T.values)
f = eda.plot_float_dist(df_r2, ['r2'], log=False, txtadd=f'Bayesian R2 for `yhat` vs `y` in `{mdla1.mdl_id}`')

# %% [markdown]
# **Observe:**
#
# + The `RMSE` distribution looks a little broader than for `mdla0`, and the mean is substantially better
# + The `Bayesian R^2` also looks substantially lower than for `mdla0`

# %% [markdown]
# ### 2.4.4 Jointplots of PPC marginals - another method to intuit PPC covariance

# %% [markdown]
# #### Mean

# %%
rv = 'mhat'
cols = mdla1.coords[f'{rv}_nm']
mhat = az.extract(mdla1.idata, group='posterior_predictive', var_names=rv).values
dfp = pd.DataFrame(np.nanmean(mhat, axis=2), columns=cols)
f = eda.plot_joint_numeric(data=dfp, ft0=cols[0], ft1=cols[1], kind='kde+scatter', 
            colori=2, subtitle='In-Sample Posterior Predictive Marginals (mean)')

# %% [markdown]
# **Observe:**
#
# + Now we see non-zero correlation $\rho \approx -0.45$ which is closer to our observed data, good!

# %% [markdown]
# #### Quantiles

# %%
qs = [0.03, 0.25, 0.5, 0.75, 0.97]
dfp = pd.DataFrame(np.quantile(mhat, qs, axis=2).reshape(len(qs)*mdla1.n, 2), columns=cols)
dfp['q'] = np.repeat([f'{q}'  for q in qs], mdla1.n)
f = eda.plot_joint_numeric(data=dfp, ft0=cols[0], ft1=cols[1], hue='q', kind='kde', # legendpos='lower right',
            subtitle='In-Sample Posterior Predictive Marginals (quantiles)')

# %% [markdown]
# **Observe**
#
# + The PPC quantile range covers the range of the observed data quite well
#
# > So the marginals fit well, _and_ the covariance in the data seems to have been captured by the model

# %% [markdown]
# ---

# %% [markdown]
# ## 2.5 Evaluate LOO-PIT (In-Sample)

# %%
f = mt.plot_loo_pit(mdla1, data_pairs={'mhat': 'mhat'})

# %% [markdown]
# **Observe**
#
# + Seems like a good fit based on the marginals
# + Again we note this doesn't reflect the latent covariance structure in the observed data

# %% [markdown]
# ---

# %% [markdown]
# ## 2.6 Compare Log-Likelihood vs other models

# %% [markdown]
# ### 2.6.1 Reinstantiate earlier models for comparison

# %%
mdla0 = copula.ModelA0(obs_m0=dfx_m0_train, obs_m1=dfx_m1_train, obs_nm='dfx_train',
                    dfx_creatord={'m0':dfx_creator_m0, 'm1':dfx_creator_m1})
mdla0.build()
mdla0_idata = mdlio.read_idata(mdl=mdla0)
mdla0.update_idata(idata=mdla0_idata)

# %% [markdown]
# ### 2.6.2 Compare `mhat`

# %%
mdl_dict = {'mdla0': mdla0, 'mdla1': mdla1}
f, dcomp = mt.plot_compare(mdl_dict, yhats=['mhat'])
fqn = figio.write(f, fn='101_2.6_compare_elpd_mhat')
_ = [display(d) for d in dcomp.values()]
# Out:
#                              rank    elpd_loo     p_loo  elpd_diff  \
# mdla0\nmdla0_v130_dfx_train     0 -198.161338  3.346015   0.000000
# mdla1\nmdla1_v110_dfx_train     1 -253.310990  2.914442  55.149652
#
#                                    weight         se       dse  warning scale
# mdla0\nmdla0_v130_dfx_train  1.000000e+00  15.243868  0.000000    False   log
# mdla1\nmdla1_v110_dfx_train  1.739409e-11  14.078224  5.530082    False   log

# %% [markdown]
# **Observe:**
#
# + Curiously, the more basic `mdla0` appears to have better in-sample `elpd_loo` for `mhat`
# + This could be because in `mdla0` each marginal is able to fit independently, (potentially overfitting)
#
# > Unfortunately, in order to compare the `yhat` requires us to go under the hood of arviz and compute the
# > log-likelihood directly. This is difficult and prone to error, so for now we'll move on.

# %% [markdown]
# ---

# %% [markdown]
# ## 2.7 Evaluate Fitted Posterior Parameters

# %% [markdown]
# NOTE: Because this is a synthetic dataset, we can evaluate parameter recovery

# %% [markdown]
# ### 2.7.1 Univariate priors and hyperpriors on linear models

# %%
# get ref values from copula builder
refs = [cb.ref_vals['m0_params']['sigma'], cb.ref_vals['m1_params']['sigma'],
        cb.ref_vals['m0_params']['mu'], cb.ref_vals['m1_params']['mu']]
f = mt.facetplot_krushke(mdl=mdla1, group=GRP, txtadd='hyperpriors on marginals',
        rvs=mdla1.rvs_marg, ref_vals=refs, m=4, rvs_hack=1)

# %% [markdown]
# **Observe:**
#
# + `sigma: S0`: $\mathbb{E} \approx 0.4$: a little lower and narrower than prior. $\text{HDI}_{94} \ni \text{refval}$
# + `sigma: S1`: $\mathbb{E} \approx 0.9$: narrower than prior, but same location. $\text{HDI}_{94} \ni \text{refval}$
# + `beta_m0: intercept`: $\mathbb{E} \approx 0.2, \text{HDI}_{94} \not\ni 0$: slightly positive, substantial effect. $\text{HDI}_{94} \ni \text{refval}$
# + `beta_m1: intercept`: $\mathbb{E} \approx 2.0, \text{HDI}_{94} \not\ni 0$: more positive, substantial effect. $\text{HDI}_{94} \ni \text{refval}$.
# + Parameter recovery looks good for all.

# %% [markdown]
# ### 2.7.2 Bivariate hyperpriors - looking for correlations

# %%
refsd = {'sigma\ns0': cb.ref_vals['m0_params']['sigma'], 'sigma\ns1' :cb.ref_vals['m1_params']['sigma'],
        'beta_m0\nintercept': cb.ref_vals['m0_params']['mu'], 'beta_m1\nintercept': cb.ref_vals['m1_params']['mu']}
f = mt.pairplot_corr(mdl=mdla1, rvs=mdla1.rvs_marg, ref_vals=refsd)

# %% [markdown]
# **Observe:**
#
# + This is another view of the parameter recovery for marginal linear submodel parameters - which seems good for all.
# + Note lack of correlation between `beta_m0` and `beta_m1` because they're not correlated in the model

# %% [markdown]
# ### ~~2.7.3 Copula Structure~~

# %% [markdown]
# Placeholder section unused, because this model doesn't use a copula!

# %%
# None

# %% [markdown]
# ---

# %% [markdown]
# ## 2.8 Forecast $\hat{y}$ on Out-of-Sample Holdout Set

# %% [markdown]
# **Discussion**
#
#
# Strictly speaking, our Bayesian modeling workflow does not require us to evaluate the model on an **out-of-sample**
# Holdout (aka Test) dataset because we use in-sample Pareto-smoothed Leave-One-Out (LOO-PIT) cross-validation testing
# shown above. The LOO-PIT method is more powerful and lets us fit & evaluate the model using the full Working set
#
# However, because this model is parametric, we _can_ make a **forecast** $\hat{y} = \hat{M_{0}} \cdot \hat{M_{1}}$ for new datapoints in an **out-of-sample dataset**.
#
# Furthermore here specifically, we use the `holdout` dataset defined above an out-of-sample dataset, where we also know
# the true value, so we can directly compare to the predictions for the sake of further understanding the model behaviour

# %% [markdown]
# ### 2.8.1 Sample PPC on `holdout` set

# %%
mdla1.replace_obs(obsd={'obs_m0':dfx_m0_holdout, 'obs_m1':dfx_m1_holdout}, obs_nm='dfx_holdout')
mdla1.build()
f_idata = mdla1.sample_posterior_predictive(store_ppc=False, ppc_insample=False, var_names=mdla1.rvs_ppc + mdla1.rvs_det)
f_idata

# %% [markdown]
# ### 2.8.2 View PPC on marginal distributions $M_{0}$, $M_{1}$ on individual observations $i$

# %% [markdown]
# Let's view the marginals and their correlation (or lack thereof in this simple no-copula model)

# %%
dfp = az.extract(f_idata, group='predictions', var_names=['mhat']).to_dataframe().drop(['chain', 'draw'], axis=1).unstack(1)
dfp.columns = dfp.columns.droplevel(0)

idx_m0 = (dfp['m0hat'] >= dfp['m0hat'].quantile(0.03)) & (dfp['m0hat'] <= dfp['m0hat'].quantile(0.97))
idx_m1 = (dfp['m1hat'] >= dfp['m1hat'].quantile(0.03)) & (dfp['m1hat'] <= dfp['m1hat'].quantile(0.97))

kde_kws = dict(zorder=0, levels=7, cut=0, fill=True, legend=True, warn_singular=False)
scatter_kws = dict(alpha=1, marker="o", linewidths=0.05, edgecolor="#dddddd", s=100, c='C1', zorder=2)
g = sns.displot(x='m0hat', y='m1hat', col='oid', col_wrap=4, data=dfp.loc[idx_m0 & idx_m1], kind='kde', height=3, aspect=1, **kde_kws)
_ = g.fig.suptitle(f'Forecasted PPC KDEs (cut at $HDI_{{94}}$) for marginals $\hat{{M_{0}}}$, $\hat{{M_{1}}}$ '+
                    f'for {mdla1.n} indiv. obs in Holdout Set (with overplotted actuals)'+ f'\n{mdla1.mdl_id}')
_ = [sns.scatterplot(x='m0', y='m1', data=df_holdout.iloc[[i]], ax=ax, **scatter_kws) for i, ax in enumerate(g.axes)]
_ = g.fig.tight_layout()
figio.write(g.fig, fn=f'100_2.8.2_ppc_holdout_marginals_{mdla1.mdl_id}')

# %% [markdown]
# **Observe:**
#
# + Each subplot is the predicted joint distribution $(\hat{M_{0}}, \hat{M_{1}})$ for an individual observation `oid` in
#   the Holdout set `df_holdout`, shown as a KDE in blue shades
#   + The KDE is almost the same on each subplot because this model doesn't regress onto individual features of the
#     observations $\mathbf{x}_{i}$ (slight differences are due to natural variation in the sampling)
#   + Note the KDEs don't display a particularly strong correlation
# + Because this is a holdout set where we know the True value, we overplot it $(m_{0}, m_{1})$ to compare (orange markers)
#   + We see the True point value is captured by the predicted KDE (cut at $HDI_{94}$) in all cases: good
#   + Note this kind of introspection / evaluation vs actual values is of course wildly impractical for larger holdout sets

# %% [markdown]
# ### 2.8.3 View PPC on resultant combined distribution $\hat{y}$ on individual observations $i$

# %% [markdown]
# Let's view the resulting $\hat{y}_{i} = \hat{M_{0}} \cdot \hat{M_{1}}$ for individuals $i$

# %%
dfp = az.extract(f_idata, group='predictions', var_names=['yhat']).to_dataframe().drop(['chain', 'draw'], axis=1).reset_index()
df_holdout['y'] = df_holdout['m0'] * df_holdout['m1']

# %%
mn_pt_kws=dict(markerfacecolor='w', markeredgecolor='#333333', marker='d', markersize=8)
box_kws=dict(kind='box', sym='', orient='h', showmeans=True, whis=(3, 97), meanprops=mn_pt_kws)

g = sns.catplot(x='yhat', y='oid', data=dfp, **box_kws, height=4, aspect=3, palette='Blues', zorder=1)
_ = sns.scatterplot(x='y', y='oid', data=df_holdout.reset_index(), ax=g.axes.flatten()[0], **scatter_kws)
_ = g.fig.suptitle('Forecasted PPC boxplots for $\hat{y}$ '
                + f'for {mdla1.n} indiv. obs in Holdout Set (with overplotted actuals)\n`{mdla1.mdl_id}`')
_ = g.fig.tight_layout()
figio.write(g.fig, fn=f'100_2.8.3_ppc_holdout_y_{mdla1.mdl_id}')

# %% [markdown]
# **Observe:**
#
# + Each bar is the predicted resultant distribution $\hat{y}$ for an individual observation `oid` in the Holdout set `df_holdout`
#   + The bars are almost the same on each subplot because this model doesn't regress onto individual features of the
#     observations $\mathbf{x}_{i}$ (slight differences are due to natural variation in the sampling)
#   + We see even more clearly that variations in the Actual observations are not captured by the model, but the overall
#     behaviour looks reasonable
# + Because this is a holdout set where we know the True value, we overplot it $(m_{0}, m_{1})$ to compare (orange markers)
#   + We see the True point value is captured by the predicted KDE (cut at $HDI_{94}$) in all cases: good
#   + Note this kind of introspection / evaluation vs actual values is of course wildly impractical for larger holdout sets

# %% [markdown]
# ### 2.8.4 View PPC on summed resultant combined distribution $\sum_{i}{\hat{y}}_{i}$ on entire Holdout set

# %% [markdown]
# NOTE:
#
# + Let's view the resulting estimate of $\sum_{i}{\hat{y}}_{i}$ for the entire Holdout set. In practice, this could
#   represent a total Estimated Expected Loss Cost $\mathbb{E}_{\text{loss}}$ for a portfolio, and is critical to get right.
# + We view the distribution as a simple boxplot and an Exceedance curve (1-ECDF) to demonstrate the different ways we
#   can interpret the same data and form quantified decisions
# + In each case we overplot the equivalent Actual value $\sum_{i}{y}_{i}$ for comparision, itself a bootstrap resample
#   to give a fair representation of the natural variance in the data.

# %% [markdown]
# #### Boxplot Empirical PDF

# %%
f = eda.plot_estimate(yhat=dfp.groupby(['chain', 'draw'])['yhat'].sum().values, nobs=len(df_holdout),
                      yhat_nm='$\sum_{i}{\hat{y}}_{i}$', txtadd=f'`{mdla1.mdl_id}`',
                      y=eda.bootstrap(a=df_holdout['y'].values, summary_fn=np.sum), y_nm='bootstrapped $\sum_{i}{y}_{i}$')
figio.write(g.fig, fn=f'100_2.8.4_ppc_holdout_y_boxplot_{mdla1.mdl_id}')

# %% [markdown]
# **Observe:**
#
# + Now we can clearly see the impact: although the in-sample model fit was acceptable, the combined value $y$ is way
#   off, because this model ignores copula correlation between the marginals
# + The mean of $\sum_{i}{\hat{y}}_{i}$ is $\mu = 133$, very different the bootstrapped actual data $\sum_{i}{\hat{y}}_{i}$
#   with a mean $\mu = 96$, this is a $\frac{133}{96} \approx 38.5%$ overestimate!
# + We do see that the PPC distribution envelops the bootstrapped actual data, which is promising, and means the model
#   wouldn't necessarily be wrong to use, but there is clearly room to improve!

# %% [markdown]
# #### Exceedence Curve (1 - ECDF)

# %%
f = eda.plot_estimate(yhat=dfp.groupby(['chain', 'draw'])['yhat'].sum().values, nobs=len(df_holdout),
                      yhat_nm='$\sum_{i}{\hat{y}}_{i}$', txtadd=f'`{mdla1.mdl_id}`', exceedance=True)
figio.write(g.fig, fn=f'100_2.8.4_ppc_holdout_y_exceedance_{mdla1.mdl_id}')

# %% [markdown]
# **Observe:**
#
# + Now we get to use the full power of the quantified uncertainty:
#   + We can read this curve **vertically** to determine the empirical probability of achieving a particular value $y$
#   + We can read this curve **horizontally** to determine the value $y$ at a particular probability
# + For example:
#   + The $P(0.5) \geq 121$, lower than the (right-skewed) mean we see above, but still higher than the bootstrapped mean
#   + The $P(0.01) \geq 310$, meaning that the probability that $\hat{y} \geq 310$ is only $0.01$ aka $1\%$ aka 1-in-100
#
# > After all this evaluation, we move to the next model in the series in the next notebook

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # Notes

# %%
# Sanity-check Lognorm Implementations `scipy` vs `pymc`
mt.sanity_check_lognorm(cb.ref_vals['m0_params']['mu'], cb.ref_vals['m1_params']['sigma'])

# %%
# %load_ext watermark
# %watermark -a "jonathan.sedar@oreum.io" -udtmv -iv -p pymc,pytensor

# %% [markdown]
# ---
# **Oreum OÜ &copy; 2024**
